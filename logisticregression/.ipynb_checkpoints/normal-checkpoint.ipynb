# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
x,y = make_classification(n_samples=1000,n_features=2,n_informative=2,n_redundant=0,n_classes=2,n_clusters_per_class=1)

# %%
print(x.shape,y.shape)
# Out:
# (1000, 2) (1000,)

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
X = np.ones((x.shape[0],x.shape[1]+1))
X[:,1:] = x
print(X.shape)
# Out:
# (1000, 3)

# %% [markdown]
# # Logarithm

# %%
def hypothesis(theta,x):
    return 1/(1+np.exp(-np.dot(theta,x)))

# %%
def pred(theta,x):
    hx = hypothesis(theta,x)
    if hx>=0.5:
        return 1
    else:
        return 0

# %%
def error(theta,x,y):
    err=0
    m = x.shape[0]
    for ix in range(m):
        hx = hypothesis(theta,x[ix])
        err += y[ix]*np.log2(hx)+(1-y[ix])*np.log2(1-hx)
    return -err/m

# %%
def gradient(x,y,theta):
    grad = np.zeros(x.shape[1])
    m = x.shape[0]
    for ix in range(m):
        hx = hypothesis(theta,x[ix])
        grad += (y[ix]-hx)*x[ix]
    
    return -grad/m

# %%
def gradientdescent(x,y,lr=0.01):
    theta = np.zeros(x.shape[1])
    err = []
    while(True):
        terr = error(theta,x,y)
        err.append(terr)
        theta = theta - lr*gradient(x,y,theta)
        if(len(err)>=2&&err[-2]-err[-1] < 0.001):
            break
    print(err)
    return theta,err

# %%
theta,err = gradientdescent(X,y)
# Out:
# [-1, 1.0, 0.99621573976925304, 0.99246249610035919, 0.98874000396218209, 0.98504799930724196, 0.98138621911444157, 0.9777544014303402, 0.97415228540900922, 0.97057961135048276, 0.96703612073781009, 0.96352155627271163, 0.96003566190988066, 0.95657818288992402, 0.95314886577096003, 0.94974745845890718, 0.94637371023646588, 0.94302737179080609, 0.93970819524001181, 0.93641593415826052, 0.93315034359978788, 0.92991118012165863, 0.92669820180533424, 0.923511168277098, 0.92034984072733894, 0.91721398192870718, 0.9141033562532036, 0.91101772968816896, 0.90795686985124568, 0.90492054600431016, 0.90190852906640218, 0.89892059162568727, 0.89595650795045045, 0.89301605399916006, 0.89009900742965131, 0.88720514760738789, 0.88433425561289813, 0.88148611424834045, 0.87866050804328033, 0.87585722325967075, 0.87307604789606474, 0.87031677169105737, 0.86757918612604767, 0.864863084427273, 0.86216826156714743, 0.8594945142649848, 0.85684164098705351, 0.85420944194601378, 0.85159771909978332, 0.84900627614980451, 0.84643491853877717, 0.84388345344782911, 0.84135168979320596, 0.83883943822243523, 0.836346511110029, 0.83387272255272127, 0.83141788836426744, 0.82898182606981197, 0.82656435489986813, 0.82416529578388409, 0.82178447134345278, 0.8194217058851655, 0.81707682539311255, 0.81474965752107353, 0.81244003158439004, 0.81014777855153597, 0.8078727310354179, 0.80561472328441186, 0.80337359117312201, 0.80114917219293613, 